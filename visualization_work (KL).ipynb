# %%
import pandas as pd

# %%
df=pd.read_csv('spaceX.csv')
df['launch_date_utc']=pd.to_datetime(df['launch_date_utc'])#.strftime('%Y-%m-%d')
df=df.set_index('launch_date_utc')
df.resample('m').size().plot()
# df.groupby('launch_date_utc').size().plot()
# df.resample('d')')

# %%
df.groupby('')
