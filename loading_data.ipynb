# %%
import pandas as pd

# %%
pd.read_csv('spaceX.csv')
# Out:
#      Unnamed: 0  flight_number                 mission_name   mission_id  \
# 0             0              1                    FalconSat           []
# 1             1              2                      DemoSat           []
# 2             2              3                  Trailblazer           []
# 3             3              3                  Trailblazer           []
# 4             4              4                       RatSat           []
# ..          ...            ...                          ...          ...
# 131         131            107                       Crew-1  ['EE86F74']
# 132         132            108  Sentinel-6 Michael Freilich           []
# 133         133            109           Starlink-15 (v1.0)           []
# 134         134            110                       CRS-21  ['EE86F74']
# 135         135            110                        SXM-7           []
#
#      launch_year           launch_date_utc rocket_id rocket_name rocket_type  \
# ...
